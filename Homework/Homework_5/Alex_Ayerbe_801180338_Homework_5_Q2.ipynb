# %%
#Used for creating the train and validation data
from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import torch
import torch.optim as optim

#Data Visualization:
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/HamedTabkhi/Intro-to-ML/main/Dataset/Housing.csv'
df = pd.read_csv(url)

# %% [markdown]
# Pre-Processing and Training

# %%
varlist = ['area', 'bedrooms', 'bathrooms', 'stories', 'parking']
y = df.pop('price')
x = df[varlist].values

t_un = torch.tensor(StandardScaler().fit_transform(x), dtype=torch.float32)
t_u = torch.tensor(x, dtype=torch.float32)
t_c = torch.tensor(y, dtype=torch.float32)

# %% [markdown]
# Splitting Training and Validation Set

# %%
samples = t_un.shape[0]
values = int(0.2 * samples)
shuffle = torch.randperm(samples)

train_idx = shuffle[:-values]
valid_idx = shuffle[-values:]

t_un_train = t_un[train_idx]
t_un_valid = t_un[valid_idx]

t_u_train = t_u[train_idx]
t_u_valid = t_u[valid_idx]

t_c_train = t_c[train_idx]
t_c_valid = t_c[valid_idx]

# %% [markdown]
# Linear Regression Training

# %%
# Model and Training Functions
def lin_model(t_u, *params):
    params = torch.stack(params)
    return torch.matmul(t_u, params[:-1]) + params[-1]

def cost(t_p, t_c):
    squared_diffs = (t_p - t_c)**2
    return squared_diffs.mean()

def lin_training(epochs, optimizer, params, t_u_train, t_u_valid, t_c_train, t_c_valid):
    train_losses = []
    valid_losses = []
    for epoch in range(1, epochs+1):
        t_p_train = lin_model(t_u_train, *params)
        train_loss = cost(t_p_train, t_c_train)

        t_p_valid = lin_model(t_u_valid, *params)
        valid_loss = cost(t_p_valid, t_c_valid)

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()

        train_losses.append(train_loss.detach().clone())
        valid_losses.append(valid_loss.detach().clone())

        if epoch % 500 == 0:
            print(f'Epochs: {epoch}, \tTraining Loss: {train_loss.item()}, \tValidation Loss: {valid_loss.item()}')
    return params, train_losses, valid_losses

# %% [markdown]
# Linear Regression Optimizer Loop and Plots

# %%
# Optimizer and Training for different Learning Rates
def run_optimizer(optimizer_type, learning_rates, t_u_train, t_u_valid, t_c_train, t_c_valid):
    results = {}
    for lr in learning_rates:
        # Initialize params as separate tensors for each parameter
        params = [torch.tensor(1.0, requires_grad=True) for _ in range(t_u_train.shape[1])] + [torch.tensor(0.0, requires_grad=True)]
        if optimizer_type == 'SGD':
            optimizer = optim.SGD(params, lr=lr)
        elif optimizer_type == 'Adam':
            optimizer = optim.Adam(params, lr=lr)

        print(f"### {optimizer_type} Optimized Linear Model with Learning Rate {lr}")
        model, trainLoss, validLoss = lin_training(5000, optimizer, params, t_u_train, t_u_valid, t_c_train, t_c_valid)

        results[lr] = {
            'trainLoss': np.array([item.item() for item in trainLoss]),
            'validLoss': np.array([item.item() for item in validLoss])
        }
    return results

# Define learning rates
sgd_learning_rates = [1e-1, 1e-2, 1e-3, 1e-4]
adam_learning_rates = [1e-1, 1e-2, 1e-3, 1e-4]

# Run SGD optimizer with scaled inputs
sgd_results = run_optimizer('SGD', sgd_learning_rates, t_un_train, t_un_valid, t_c_train, t_c_valid)

# Run Adam optimizer with unscaled inputs
adam_results = run_optimizer('Adam', adam_learning_rates, t_u_train, t_u_valid, t_c_train, t_c_valid)

# Plotting Results
def plot_loss(results, optimizer_type):
    plt.figure(figsize=(10, 10))
    plt.suptitle(f'{optimizer_type} Optimized Linear Regression Loss utilizing 5 inputs')

    for i, (lr, result) in enumerate(results.items(), 1):
        train_loss = result['trainLoss']
        valid_loss = result['validLoss']

        plt.subplot(2, 2, i)
        plt.plot(train_loss, color='blue', label='Training Loss')
        plt.plot(valid_loss, color='red', label='Validation Loss')
        plt.title(f'Loss with Learning Rate of {lr}')
        plt.legend()

    plt.tight_layout()
    plt.show()

# Plot loss for both optimizers
plot_loss(sgd_results, 'SGD')
plot_loss(adam_results, 'Adam')
# Out:
# ### SGD Optimized Linear Model with Learning Rate 0.1
# Epochs: 500, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466215038976.0
# Epochs: 1000, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466215038976.0
# Epochs: 1500, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466215038976.0
# Epochs: 2000, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466215038976.0
# Epochs: 2500, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466215038976.0
# Epochs: 3000, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466215038976.0
# Epochs: 3500, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466215038976.0
# Epochs: 4000, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466215038976.0
# Epochs: 4500, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466215038976.0
# Epochs: 5000, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466215038976.0
# ### SGD Optimized Linear Model with Learning Rate 0.01
# Epochs: 500, 	Training Loss: 1551003549696.0, 	Validation Loss: 1465922748416.0
# Epochs: 1000, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466211368960.0
# Epochs: 1500, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466212155392.0
# Epochs: 2000, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466212155392.0
# Epochs: 2500, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466212155392.0
# Epochs: 3000, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466212155392.0
# Epochs: 3500, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466212155392.0
# Epochs: 4000, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466212155392.0
# Epochs: 4500, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466212155392.0
# Epochs: 5000, 	Training Loss: 1551001321472.0, 	Validation Loss: 1466212155392.0
# ### SGD Optimized Linear Model with Learning Rate 0.001
# Epochs: 500, 	Training Loss: 4707858776064.0, 	Validation Loss: 4177518133248.0
# Epochs: 1000, 	Training Loss: 1984141459456.0, 	Validation Loss: 1761258242048.0
# Epochs: 1500, 	Training Loss: 1613664747520.0, 	Validation Loss: 1473846837248.0
# Epochs: 2000, 	Training Loss: 1560804065280.0, 	Validation Loss: 1453130383360.0
# Epochs: 2500, 	Training Loss: 1552745496576.0, 	Validation Loss: 1458140479488.0
# Epochs: 3000, 	Training Loss: 1551369633792.0, 	Validation Loss: 1462176972800.0
# Epochs: 3500, 	Training Loss: 1551093334016.0, 	Validation Loss: 1464217632768.0
# Epochs: 4000, 	Training Loss: 1551027404800.0, 	Validation Loss: 1465192546304.0
# Epochs: 4500, 	Training Loss: 1551009185792.0, 	Validation Loss: 1465670303744.0
# Epochs: 5000, 	Training Loss: 1551003811840.0, 	Validation Loss: 1465911083008.0
# ### SGD Optimized Linear Model with Learning Rate 0.0001
# Epochs: 500, 	Training Loss: 21950302781440.0, 	Validation Loss: 19199686606848.0
# Epochs: 1000, 	Training Loss: 17999532654592.0, 	Validation Loss: 15822529495040.0
# Epochs: 1500, 	Training Loss: 14848852230144.0, 	Validation Loss: 13105729896448.0
# Epochs: 2000, 	Training Loss: 12326084280320.0, 	Validation Loss: 10912836616192.0
# Epochs: 2500, 	Training Loss: 10298991837184.0, 	Validation Loss: 9138043092992.0
# Epochs: 3000, 	Training Loss: 8665180405760.0, 	Validation Loss: 7698516017152.0
# Epochs: 3500, 	Training Loss: 7344894246912.0, 	Validation Loss: 6529003028480.0
# Epochs: 4000, 	Training Loss: 6275534946304.0, 	Validation Loss: 5577674063872.0
# Epochs: 4500, 	Training Loss: 5407733972992.0, 	Validation Loss: 4803158605824.0
# Epochs: 5000, 	Training Loss: 4702311284736.0, 	Validation Loss: 4172236455936.0
# ### Adam Optimized Linear Model with Learning Rate 0.1
# Epochs: 500, 	Training Loss: 24250209533952.0, 	Validation Loss: 21014417244160.0
# Epochs: 1000, 	Training Loss: 21851031994368.0, 	Validation Loss: 18862405844992.0
# Epochs: 1500, 	Training Loss: 19650003861504.0, 	Validation Loss: 16887992811520.0
# Epochs: 2000, 	Training Loss: 17631201460224.0, 	Validation Loss: 15076901781504.0
# Epochs: 2500, 	Training Loss: 15781707382784.0, 	Validation Loss: 13417553330176.0
# Epochs: 3000, 	Training Loss: 14091107172352.0, 	Validation Loss: 11900613033984.0
# Epochs: 3500, 	Training Loss: 12551024803840.0, 	Validation Loss: 10518573088768.0
# Epochs: 4000, 	Training Loss: 11154642436096.0, 	Validation Loss: 9265323442176.0
# Epochs: 4500, 	Training Loss: 9896251621376.0, 	Validation Loss: 8135751761920.0
# Epochs: 5000, 	Training Loss: 8770883682304.0, 	Validation Loss: 7125403697152.0
# ### Adam Optimized Linear Model with Learning Rate 0.01
# Epochs: 500, 	Training Loss: 26590088003584.0, 	Validation Loss: 23113110650880.0
# Epochs: 1000, 	Training Loss: 26320551542784.0, 	Validation Loss: 22871361454080.0
# Epochs: 1500, 	Training Loss: 26053141594112.0, 	Validation Loss: 22631516471296.0
# Epochs: 2000, 	Training Loss: 25787740717056.0, 	Validation Loss: 22393475039232.0
# Epochs: 2500, 	Training Loss: 25524246151168.0, 	Validation Loss: 22157144883200.0
# Epochs: 3000, 	Training Loss: 25262574010368.0, 	Validation Loss: 21922446311424.0
# Epochs: 3500, 	Training Loss: 25002663477248.0, 	Validation Loss: 21689324797952.0
# Epochs: 4000, 	Training Loss: 24744462123008.0, 	Validation Loss: 21457730011136.0
# Epochs: 4500, 	Training Loss: 24487923810304.0, 	Validation Loss: 21227634688000.0
# Epochs: 5000, 	Training Loss: 24233048539136.0, 	Validation Loss: 20999024148480.0
# ### Adam Optimized Linear Model with Learning Rate 0.001
# Epochs: 500, 	Training Loss: 26834108416000.0, 	Validation Loss: 23331973627904.0
# Epochs: 1000, 	Training Loss: 26806853828608.0, 	Validation Loss: 23307520835584.0
# Epochs: 1500, 	Training Loss: 26779609726976.0, 	Validation Loss: 23283091111936.0
# Epochs: 2000, 	Training Loss: 26752394985472.0, 	Validation Loss: 23258680262656.0
# Epochs: 2500, 	Training Loss: 26725197021184.0, 	Validation Loss: 23234288287744.0
# Epochs: 3000, 	Training Loss: 26698015834112.0, 	Validation Loss: 23209913090048.0
# Epochs: 3500, 	Training Loss: 26670855618560.0, 	Validation Loss: 23185548378112.0
# Epochs: 4000, 	Training Loss: 26643707985920.0, 	Validation Loss: 23161202540544.0
# Epochs: 4500, 	Training Loss: 26616577130496.0, 	Validation Loss: 23136871383040.0
# Epochs: 5000, 	Training Loss: 26589465149440.0, 	Validation Loss: 23112548614144.0
# ### Adam Optimized Linear Model with Learning Rate 0.0001
# Epochs: 500, 	Training Loss: 26858615734272.0, 	Validation Loss: 23353949683712.0
# Epochs: 1000, 	Training Loss: 26855885242368.0, 	Validation Loss: 23351500210176.0
# Epochs: 1500, 	Training Loss: 26853156847616.0, 	Validation Loss: 23349052833792.0
# Epochs: 2000, 	Training Loss: 26850426355712.0, 	Validation Loss: 23346605457408.0
# Epochs: 2500, 	Training Loss: 26847697960960.0, 	Validation Loss: 23344155983872.0
# Epochs: 3000, 	Training Loss: 26844967469056.0, 	Validation Loss: 23341708607488.0
# Epochs: 3500, 	Training Loss: 26842236977152.0, 	Validation Loss: 23339261231104.0
# Epochs: 4000, 	Training Loss: 26839508582400.0, 	Validation Loss: 23336815951872.0
# Epochs: 4500, 	Training Loss: 26836782284800.0, 	Validation Loss: 23334368575488.0
# Epochs: 5000, 	Training Loss: 26834051792896.0, 	Validation Loss: 23331921199104.0

# %% [markdown]
# Answer to Question 2.c
